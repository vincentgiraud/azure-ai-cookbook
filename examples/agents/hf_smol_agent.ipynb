# %%
import os
from dotenv import load_dotenv
from smolagents.models import AzureOpenAIServerModel
from smolagents import CodeAgent, DuckDuckGoSearchTool, VisitWebpageTool

load_dotenv()
# Out:
# True

# %%
model = AzureOpenAIServerModel(
    model_id = os.environ.get("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME"),
    api_key=os.environ.get("AZURE_OPENAI_API_KEY"),
    api_version=os.environ.get("AZURE_OPENAI_API_VERSION"),
    azure_endpoint=os.environ.get("AZURE_OPENAI_ENDPOINT")
)

# %% [markdown]
# https://huggingface.co/docs/smolagents/en/guided_tour?Pick+a+LLM=Azure+OpenAI

# %%
agent = CodeAgent(tools=[], model=model, additional_authorized_imports=['requests', 'bs4'])
agent.run("Could you get me the title of the page at url 'https://huggingface.co/blog'?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Could you get me the title of the page at url 'https://huggingface.co/blog'?                                    │
# │                                                                                                                 │
# ╰─ AzureOpenAIServerModel - gpt-4o-glob-2024-05-13 ───────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import requests
#   from bs4 import BeautifulSoup
#
#   url = 'https://huggingface.co/blog'
#   response = requests.get(url)
#   print(response.content)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# b'<!doctype html>\n<html class="">\n\t<head>\n\t\t<meta charset="utf-8" />\n\t\t<meta name="viewport"
# content="width=device-width, initial-scale=1.0, user-scalable=no" />\n\t\t<meta name="description"
# content="We\xe2\x80\x99re on a journey to advance and democratize artificial intelligence through open source and
# open science." />\n\t\t<meta property="fb:app_id" content="1321688464574422" />\n\t\t<meta name="twitter:card"
# content="summary_large_image" />\n\t\t<meta name="twitter:site" content="@huggingface" />\n\t\t<meta
# name="twitter:image" content="https://huggingface.co/front/thumbnails/blog.png" />\n\t\t<meta property="og:title"
# content="Hugging Face \xe2\x80\x93 Blog" />\n\t\t<meta property="og:type" content="website" />\n\t\t<meta
# property="og:url" content="https://huggingface.co/blog" />\n\t\t<meta property="og:image"
# content="https://huggingface.co/front/thumbnails/blog.png" />\n\n\t\t<link rel="stylesheet"
# href="/front/build/kube-6eb1cac/style.css" />\n\n\t\t<link rel="preconnect" href="https://fonts.gstatic.com"
# />\n\t\t<link\n\t\t\thref="https://fonts.googleapis.com/css2?family=Source+Sans+Pro:ital,wght@0,200;0,300;0,400;0,6
# 00;0,700;0,900;1,200;1,300;1,400;1,600;1,700;1,900&display=swap"\n\t\t\trel="stylesheet"\n\t\t/>\n\t\t<link\n\t\t\t
# href="https://fonts.googleapis.com/css2?family=IBM+Plex+Mono:wght@400;600;700&display=swap"\n\t\t\trel="stylesheet"
# \n\t\t/>\n\n\t\t<link\n\t\t\trel="preload"\n\t\t\thref="https://cdnjs.cloudflare.com/ajax/libs/KaTeX/0.12.0/katex.m
# in.css"\n\t\t\tas="style"\n\t\t\tonload="this.onload=null;this.rel=\'stylesheet\'"\n\t\t/>\n\t\t<noscript>\n\t\t\t<
# link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/KaTeX/0.12.0/katex.min.css"
# />\n\t\t</noscript>\n\n\t\t<script>const guestTheme = document.cookie.match(/theme=(\\w+)/)?.[1];
# document.documentElement.classList.toggle(\'dark\', guestTheme === \'dark\' || ( (!guestTheme || guestTheme ===
# \'system\') && window.matchMedia(\'(prefers-color-scheme: dark)\').matches));</script>\n<link rel="canonical"
# href="https://huggingface.co/blog">  <!-- HEAD_svelte-vwinwk_START --><link rel="alternate"
# type="application/rss+xml" href="/blog/feed.xml" title="Hugging Face Blog"><!-- HEAD_svelte-vwinwk_END
# -->\n\n\t\t<title>Hugging Face \xe2\x80\x93
# Blog</title>\n\n\t\t<script\n\t\t\tdefer\n\t\t\tdata-domain="huggingface.co"\n\t\t\tevent-loggedIn="false"\n\t\t\ts
# rc="/js/script.pageview-props.js"\n\t\t></script>\n\t\t<script>\n\t\t\twindow.plausible =\n\t\t\t\twindow.plausible
# ||\n\t\t\t\tfunction () {\n\t\t\t\t\t(window.plausible.q = window.plausible.q ||
# []).push(arguments);\n\t\t\t\t};\n\t\t</script>\n\t\t<script>\n\t\t\twindow.hubConfig =
# {"features":{"signupDisabled":false},"sshGitUrl":"git@hf.co","moonHttpUrl":"https:\\/\\/huggingface.co","captchaApi
# Key":"bd5f2066-93dc-4bdd-a64b-a24646ca3859","captchaDisabledOnSignup":true,"datasetViewerPublicUrl":"https:\\/\\/da
# tasets-server.huggingface.co","stripePublicKey":"pk_live_x2tdjFXBCvXo2FFmMybezpeM00J6gPCAAc","environment":"product
# ion","userAgent":"HuggingFace
# (production)","spacesIframeDomain":"hf.space","spacesApiUrl":"https:\\/\\/api.hf.space","docSearchKey":"ece5e02e573
# 00e17d152c08056145326e90c4bff3dd07d7d1ae40cf1c8d39cb6","logoDev":{"apiUrl":"https:\\/\\/img.logo.dev\\/","apiKey":"
# pk_UHS2HZOeRnaSOdDp7jbd5w"}};\n\t\t</script>\n\t\t<script type="text/javascript"
# src="https://de5282c3ca0c.edge.sdk.awswaf.com/de5282c3ca0c/526cf06acb0d/challenge.js"
# defer></script>\n\t</head>\n\t<body class="flex flex-col min-h-dvh bg-white dark:bg-gray-950 text-black
# ArticlesPage">\n\t\t\n\n<div class="flex min-h-dvh flex-col"><div class="SVELTE_HYDRATER contents"
# data-target="SystemThemeMonitor" data-props="{&quot;isLoggedIn&quot;:false}"></div>\n\n\t<div
# class="SVELTE_HYDRATER contents" data-target="MainHeader"
# data-props="{&quot;classNames&quot;:&quot;&quot;,&quot;isWide&quot;:false,&quot;isZh&quot;:false,&quot;isPro&quot;:
# false}"><header class="border-b border-gray-100 "><div class="w-full px-4 container flex h-16 items-center"><div
# class="flex flex-1 items-center"><a class="mr-5 flex flex-none items-center lg:mr-6" href="/"><img alt="Hugging
# Face\'s logo" class="w-7 md:mr-2" src="/front/assets/huggingface_logo-noborder.svg">\n\t\t\t\t<span class="hidden
# whitespace-nowrap text-lg font-bold md:block">Hugging Face</span></a>\n\t\t\t<div class="relative flex-1
# lg:max-w-sm mr-2 sm:mr-4 md:mr-3 xl:mr-6"><input autocomplete="off" class="w-full dark:bg-gray-950 pl-8
# form-input-alt h-9 pr-3 focus:shadow-xl " name="" placeholder="Search models, datasets, users..."
# spellcheck="false" type="text" value="">\n\t<svg class="absolute left-2.5 text-gray-400 top-1/2 transform
# -translate-y-1/2" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true"
# focusable="false" role="img" width="1em" height="1em" preserveAspectRatio="xMidYMid meet" viewBox="0 0 32 32"><path
# d="M30 28.59L22.45 21A11 11 0 1 0 21 22.45L28.59 30zM5 14a9 9 0 1 1 9 9a9 9 0 0 1-9-9z"
# fill="currentColor"></path></svg>\n\t</div>\n\t\t\t<div class="flex flex-none items-center justify-center p-0.5
# place-self-stretch lg:hidden"><button class="relative z-40 flex h-6 w-8 items-center justify-center"
# type="button"><svg width="1em" height="1em" viewBox="0 0 10 10" class="text-xl" xmlns="http://www.w3.org/2000/svg"
# xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" focusable="false" role="img"
# preserveAspectRatio="xMidYMid meet" fill="currentColor"><path fill-rule="evenodd" clip-rule="evenodd" d="M1.65039
# 2.9999C1.65039 2.8066 1.80709 2.6499 2.00039 2.6499H8.00039C8.19369 2.6499 8.35039 2.8066 8.35039 2.9999C8.35039
# 3.1932 8.19369 3.3499 8.00039 3.3499H2.00039C1.80709 3.3499 1.65039 3.1932 1.65039 2.9999ZM1.65039 4.9999C1.65039
# 4.8066 1.80709 4.6499 2.00039 4.6499H8.00039C8.19369 4.6499 8.35039 4.8066 8.35039 4.9999C8.35039 5.1932 8.19369
# 5.3499 8.00039 5.3499H2.00039C1.80709 5.3499 1.65039 5.1932 1.65039 4.9999ZM2.00039 6.6499C1.80709 6.6499 1.65039
# 6.8066 1.65039 6.9999C1.65039 7.1932 1.80709 7.3499 2.00039 7.3499H8.00039C8.19369 7.3499 8.35039 7.1932 8.35039
# 6.9999C8.35039 6.8066 8.19369 6.6499 8.00039
# 6.6499H2.00039Z"></path></svg>\n\t\t</button>\n\n\t</div></div>\n\t\t<nav aria-label="Main" class="ml-auto hidden
# lg:block"><ul class="flex items-center space-x-1.5 2xl:space-x-2"><li class="hover:text-indigo-700"><a class="group
# flex items-center px-2 py-0.5 dark:text-gray-300 dark:hover:text-gray-100" href="/models"><svg class="mr-1.5
# text-gray-400 group-hover:text-indigo-500" style="" xmlns="http://www.w3.org/2000/svg"
# xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" focusable="false" role="img" width="1em" height="1em"
# preserveAspectRatio="xMidYMid meet" viewBox="0 0 24 24"><path class="uim-quaternary" d="M20.23 7.24L12 12L3.77
# 7.24a1.98 1.98 0 0 1 .7-.71L11 2.76c.62-.35 1.38-.35 2 0l6.53 3.77c.29.173.531.418.7.71z" opacity=".25"
# fill="currentColor"></path><path class="uim-tertiary" d="M12 12v9.5a2.09 2.09 0 0 1-.91-.21L4.5 17.48a2.003 2.003 0
# 0 1-1-1.73v-7.5a2.06 2.06 0 0 1 .27-1.01L12 12z" opacity=".5" fill="currentColor"></path><path class="uim-primary"
# d="M20.5 8.25v7.5a2.003 2.003 0 0 1-1 1.73l-6.62 3.82c-.275.13-.576.198-.88.2V12l8.23-4.76c.175.308.268.656.27
# 1.01z" fill="currentColor"></path></svg>\n\t\t\t\t\tModels</a>\n\t\t\t</li><li class="hover:text-red-700"><a
# class="group flex items-center px-2 py-0.5 dark:text-gray-300 dark:hover:text-gray-100" href="/datasets"><svg
# class="mr-1.5 text-gray-400 group-hover:text-red-500" style="" xmlns="http://www.w3.org/2000/svg"
# xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" focusable="false" role="img" width="1em" height="1em"
# preserveAspectRatio="xMidYMid meet" viewBox="0 0 25 25"><ellipse cx="12.5" cy="5" fill="currentColor"
# fill-opacity="0.25" rx="7.5" ry="2"></ellipse><path d="M12.5 15C16.6421 15 20 14.1046 20 13V20C20 21.1046 16.6421
# 22 12.5 22C8.35786 22 5 21.1046 5 20V13C5 14.1046 8.35786 15 12.5 15Z" fill="currentColor"
# opacity="0.5"></path><path d="M12.5 7C16.6421 7 20 6.10457 20 5V11.5C20 12.6046 16.6421 13.5 12.5 13.5C8.35786 13.5
# 5 12.6046 5 11.5V5C5 6.10457 8.35786 7 12.5 7Z" fill="currentColor" opacity="0.5"></path><path d="M5.23628
# 12C5.08204 12.1598 5 12.8273 5 13C5 14.1046 8.35786 15 12.5 15C16.6421 15 20 14.1046 20 13C20 12.8273 19.918
# 12.1598 19.7637 12C18.9311 12.8626 15.9947 13.5 12.5 13.5C9.0053 13.5 6.06886 12.8626 5.23628 12Z"
# fill="currentColor"></path></svg>\n\t\t\t\t\tDatasets</a>\n\t\t\t</li><li class="hover:text-blue-700"><a
# class="group flex items-center px-2 py-0.5 dark:text-gray-300 dark:hover:text-gray-100" href="/spaces"><svg
# class="mr-1.5 text-gray-400 group-hover:text-blue-500" xmlns="http://www.w3.org/2000/svg"
# xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" focusable="false" role="img" width="1em" height="1em"
# viewBox="0 0 25 25"><path opacity=".5" d="M6.016 14.674v4.31h4.31v-4.31h-4.31ZM14.674
# 14.674v4.31h4.31v-4.31h-4.31ZM6.016 6.016v4.31h4.31v-4.31h-4.31Z" fill="currentColor"></path><path opacity=".75"
# fill-rule="evenodd" clip-rule="evenodd" d="M3 4.914C3 3.857 3.857 3 4.914 3h6.514c.884 0 1.628.6 1.848 1.414a5.171
# 5.171 0 0 1 7.31 7.31c.815.22 1.414.964 1.414 1.848v6.514A1.914 1.914 0 0 1 20.086 22H4.914A1.914 1.914 0 0 1 3
# 20.086V4.914Zm3.016 1.102v4.31h4.31v-4.31h-4.31Zm0 12.968v-4.31h4.31v4.31h-4.31Zm8.658
# 0v-4.31h4.31v4.31h-4.31Zm0-10.813a2.155 2.155 0 1 1 4.31 0 2.155 2.155 0 0 1-4.31 0Z"
# fill="currentColor"></path><path opacity=".25" d="M16.829 6.016a2.155 2.155 0 1 0 0 4.31 2.155 2.155 0 0 0 0-4.31Z"
# fill="currentColor"></path></svg>\n\t\t\t\t\tSpaces</a>\n\t\t\t</li><li class="hover:text-yellow-700
# max-xl:hidden"><a class="group flex items-center px-2 py-0.5 dark:text-gray-300 dark:hover:text-gray-100"
# href="/posts"><svg class="mr-1.5 text-gray-400 group-hover:text-yellow-500 text-yellow-500!"
# xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" focusable="false"
# role="img" width="1em" height="1em" viewBox="0 0 12 12" preserveAspectRatio="xMidYMid meet"><path
# fill="currentColor" fill-rule="evenodd" d="M3.73 2.4A4.25 4.25 0 1 1 6 10.26H2.17l-.13-.02a.43.43 0 0
# 1-.3-.43l.01-.06a.43.43 0 0 1 .12-.22l.84-.84A4.26 4.26 0 0 1 3.73 2.4Z"
# clip-rule="evenodd"></path></svg>\n\t\t\t\t\tPosts</a>\n\t\t\t</li><li class="hover:text-yellow-700"><a
# class="group flex items-center px-2 py-0.5 dark:text-gray-300 dark:hover:text-gray-100" href="/docs"><svg
# xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" role="img"
# class="mr-1.5 text-gray-400 group-hover:text-yellow-500" width="1em" height="1em" preserveAspectRatio="xMidYMid
# meet" viewBox="0 0 16 16"><path d="m2.28 3.7-.3.16a.67.67 0 0
# 0-.34.58v8.73l.01.04.02.07.01.04.03.06.02.04.02.03.04.06.05.05.04.04.06.04.06.04.08.04.08.02h.05l.07.02h.11l.04-.01
# .07-.02.03-.01.07-.03.22-.12a5.33 5.33 0 0 1 5.15.1.67.67 0 0 0 .66 0 5.33 5.33 0 0 1 5.33 0 .67.67 0 0 0
# 1-.58V4.36a.67.67 0 0 0-.34-.5l-.3-.17v7.78a.63.63 0 0 1-.87.59 4.9 4.9 0 0 0-4.35.35l-.65.39a.29.29 0 0
# 1-.15.04.29.29 0 0 1-.16-.04l-.65-.4a4.9 4.9 0 0 0-4.34-.34.63.63 0 0 1-.87-.59V3.7Z" fill="currentColor"
# class="dark:opacity-40"></path><path fill-rule="evenodd" clip-rule="evenodd" d="M8 3.1a5.99 5.99 0 0
# 0-5.3-.43.66.66 0 0 0-.42.62v8.18c0 .45.46.76.87.59a4.9 4.9 0 0 1 4.34.35l.65.39c.05.03.1.04.16.04.05 0
# .1-.01.15-.04l.65-.4a4.9 4.9 0 0 1 4.35-.34.63.63 0 0 0 .86-.59V3.3a.67.67 0 0 0-.41-.62 5.99 5.99 0 0
# 0-5.3.43l-.3.17L8 3.1Zm.73 1.87a.43.43 0 1 0-.86 0v5.48a.43.43 0 0 0 .86 0V4.97Z" fill="currentColor"
# class="opacity-40 dark:opacity-100"></path><path d="M8.73 4.97a.43.43 0 1 0-.86 0v5.48a.43.43 0 1 0 .86 0V4.96Z"
# fill="currentColor" class="dark:opacity-40"></path></svg>\n\t\t\t\t\tDocs</a>\n\t\t\t</li><li
# class="hover:text-black dark:hover:text-white"><a class="group flex items-center px-2 py-0.5 dark:text-gray-300
# dark:hover:text-gray-100" href="/enterprise"><svg class="mr-1.5 text-gray-400 group-hover:text-black
# dark:group-hover:text-white" xmlns="http://www.w3.org/2000/svg" fill="none" aria-hidden="true" focusable="false"
# role="img" width="1em" height="1em" preserveAspectRatio="xMidYMid meet" viewBox="0 0 33 27"><path
# fill="currentColor" fill-rule="evenodd" d="M13.5.7a8.7 8.7 0 0 0-7.7 5.7L1 20.6c-1 3.1.9 5.7 4.1 5.7h15c3.3 0
# 6.8-2.6 7.8-5.7l4.6-14.2c1-3.1-.8-5.7-4-5.7h-15Zm1.1 5.7L9.8
# 20.3h9.8l1-3.1h-5.8l.8-2.5h4.8l1.1-3h-4.8l.8-2.3H23l1-3h-9.5Z"
# clip-rule="evenodd"></path></svg>\n\t\t\t\t\tEnterprise</a>\n\t\t\t</li>\n\n\t\t<li><a class="group flex
# items-center px-2 py-0.5 dark:text-gray-300 dark:hover:text-gray-100"
# href="/pricing">Pricing\n\t\t\t</a></li>\n\n\t\t<li><div class="relative group">\n\t<button class="px-2 py-0.5
# hover:text-gray-500 dark:hover:text-gray-600 flex items-center " type="button">\n\t\t<svg class=" text-gray-500 w-5
# group-hover:text-gray-400 dark:text-gray-300 dark:group-hover:text-gray-100" xmlns="http://www.w3.org/2000/svg"
# xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" focusable="false" role="img" width="1em" height="1em"
# viewBox="0 0 32 18" preserveAspectRatio="xMidYMid meet"><path fill-rule="evenodd" clip-rule="evenodd" d="M14.4504
# 3.30221C14.4504 2.836 14.8284 2.45807 15.2946 2.45807H28.4933C28.9595 2.45807 29.3374 2.836 29.3374 3.30221C29.3374
# 3.76842 28.9595 4.14635 28.4933 4.14635H15.2946C14.8284 4.14635 14.4504 3.76842 14.4504 3.30221Z"
# fill="currentColor"></path><path fill-rule="evenodd" clip-rule="evenodd" d="M14.4504 9.00002C14.4504 8.53382
# 14.8284 8.15588 15.2946 8.15588H28.4933C28.9595 8.15588 29.3374 8.53382 29.3374 9.00002C29.3374 9.46623 28.9595
# 9.84417 28.4933 9.84417H15.2946C14.8284 9.84417 14.4504 9.46623 14.4504 9.00002Z" fill="currentColor"></path><path
# fill-rule="evenodd" clip-rule="evenodd" d="M14.4504 14.6978C14.4504 14.2316 14.8284 13.8537 15.2946
# 13.8537H28.4933C28.9595 13.8537 29.3374 14.2316 29.3374 14.6978C29.3374 15.164 28.9595 15.542 28.4933
# 15.542H15.2946C14.8284 15.542 14.4504 15.164 14.4504 14.6978Z" fill="currentColor"></path><path fill-rule="evenodd"
# clip-rule="evenodd" d="M1.94549 6.87377C2.27514 6.54411 2.80962 6.54411 3.13928 6.87377L6.23458 9.96907L9.32988
# 6.87377C9.65954 6.54411 10.194 6.54411 10.5237 6.87377C10.8533 7.20343 10.8533 7.73791 10.5237 8.06756L6.23458
# 12.3567L1.94549 8.06756C1.61583 7.73791 1.61583 7.20343 1.94549 6.87377Z"
# fill="currentColor"></path></svg>\n\t\t\t\n\t\t</button>\n\t\n\t\n\t</div></li>\n\t\t<li><hr class="h-5 w-0.5
# border-none bg-gray-100 dark:bg-gray-800"></li>\n\t\t<li><a class="block cursor-pointer whitespace-nowrap px-2
# py-0.5 hover:text-gray-500 dark:text-gray-300 dark:hover:text-gray-100" href="/login">Log
# In\n\t\t\t\t</a></li>\n\t\t\t<li><a class="whitespace-nowrap rounded-full border border-transparent bg-gray-900
# px-3 py-1 leading-none text-white hover:border-black hover:bg-white hover:text-black" href="/join">Sign
# Up\n\t\t\t\t\t</a></li></ul></nav></div></header></div>\n\t\n\t\n\t\n\t<div class="SVELTE_HYDRATER contents"
# data-target="SSOBanner" data-props="{}"></div>\n\t\n\t\n\n\t<main class="flex flex-1 flex-col"><div
# class="container grid grid-cols-1 gap-6 pb-8 pt-12 lg:grid-cols-4"><div class="col-span-1 lg:col-span-3
# lg:pr-12"><div class="mb-6 flex flex-col items-start justify-start gap-4 lg:mb-4 lg:flex-row lg:items-center
# lg:justify-between"><h1 class="text-3xl font-bold">Blog, Articles, and discussions</h1>\n\n\t\t\t\t<div
# class="SVELTE_HYDRATER contents" data-target="ArticlesNewButton" data-props="{&quot;hasAccess&quot;:false}"><button
# class="btn gap-1! border-blue-100! from-blue-50! to-blue-50! text-blue-500! hover:from-blue-100/60!
# hover:to-blue-100/60! dark:border-blue-500/20! dark:from-blue-500/30! dark:to-blue-500/30! dark:text-white!
# dark:hover:from-blue-500/50! dark:hover:to-blue-500/50! cursor-pointer text-base hover:shadow-none"><svg class="w-4
# mr-1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true"
# focusable="false" role="img" width="1em" height="1em" preserveAspectRatio="xMidYMid meet" viewBox="0 0 15 15"><path
# fill="currentColor" d="M3.417 12.75c-.32 0-.596-.114-.824-.342a1.126 1.126 0 0
# 1-.343-.825V3.417c0-.321.114-.597.343-.824.23-.228.503-.343.824-.343h8.166c.321 0
# .596.114.825.343.228.229.342.503.342.824v8.166c0 .32-.114.596-.342.825a1.12 1.12 0 0
# 1-.825.342zm1.166-2.333h4.084V9.25H4.583v1.167m0-2.334h5.834V6.917H4.583v1.166m0-2.333h5.834V4.583H4.583V5.75"></pa
# th></svg>\n\tNew Article\n</button>\n\n\n\n</div></div>\n\n\t\t\t<div class="flex items-start justify-between"><nav
# class="-ml-2 flex flex-wrap items-center gap-x-0.5 gap-y-2"><a href="/blog" class="bg-black text-white
# dark:bg-gray-800 dark:text-white cursor-pointer whitespace-nowrap rounded-full from-blue-500/50 to-red-500/20
# px-2.5 py-1.5 font-mono text-xs capitalize text-gray-500 max-lg:leading-none lg:py-1
# lg:text-sm">Everything</a>\n\n\t<a href="/blog?tag=community" class="from-indigo-500/30 to-orange-500/20
# hover:bg-linear-to-r hover:text-black dark:hover:text-gray-200 cursor-pointer whitespace-nowrap rounded-full px-2.5
# py-1.5 font-mono text-xs capitalize text-gray-500 max-lg:leading-none lg:py-1 lg:text-sm">community</a><a
# href="/blog?tag=guide" class="from-pink-500/30 to-teal-500/20 hover:bg-linear-to-r hover:text-black
# dark:hover:text-gray-200 cursor-pointer whitespace-nowrap rounded-full px-2.5 py-1.5 font-mono text-xs capitalize
# text-gray-500 max-lg:leading-none lg:py-1 lg:text-sm">guide</a><a href="/blog?tag=open-source-collab"
# class="from-green-500/30 to-purple-500 hover:bg-linear-to-r hover:text-black dark:hover:text-gray-200
# cursor-pointer whitespace-nowrap rounded-full px-2.5 py-1.5 font-mono text-xs capitalize text-gray-500
# max-lg:leading-none lg:py-1 lg:text-sm">open source collab</a><a href="/blog?tag=partnerships"
# class="from-red-500/30 to-fuchsia-500/20 hover:bg-linear-to-r hover:text-black dark:hover:text-gray-200
# cursor-pointer whitespace-nowrap rounded-full px-2.5 py-1.5 font-mono text-xs capitalize text-gray-500
# max-lg:leading-none lg:py-1 lg:text-sm">partnerships</a><a href="/blog?tag=research" class="from-cyan-500/30
# to-indigo-500/20 hover:bg-linear-to-r hover:text-black dark:hover:text-gray-200 cursor-pointer whitespace-nowrap
# rounded-full px-2.5 py-1.5 font-mono text-xs capitalize text-gray-500 max-lg:leading-none lg:py-1
# lg:text-sm">research</a><a href="/blog?tag=nlp" class="from-fuchsia-500/30 to-indigo-500/20 hover:bg-linear-to-r
# hover:text-black dark:hover:text-gray-200 cursor-pointer whitespace-nowrap rounded-full px-2.5 py-1.5 font-mono
# text-xs capitalize text-gray-500 max-lg:leading-none lg:py-1 lg:text-sm">NLP</a><a href="/blog?tag=audio"
# class="from-indigo-500/30 to-orange-500/20 hover:bg-linear-to-r hover:text-black dark:hover:text-gray-200
# cursor-pointer whitespace-nowrap rounded-full px-2.5 py-1.5 font-mono text-xs capitalize text-gray-500
# max-lg:leading-none lg:py-1 lg:text-sm">Audio</a><a href="/blog?tag=cv" class="from-pink-500/30 to-teal-500/20
# hover:bg-linear-to-r hover:text-black dark:hover:text-gray-200 cursor-pointer whitespace-nowrap rounded-full px-2.5
# py-1.5 font-mono text-xs capitalize text-gray-500 max-lg:leading-none lg:py-1 lg:text-sm">CV</a><a
# href="/blog?tag=rl" class="from-green-500/30 to-purple-500 hover:bg-linear-to-r hover:text-black
# dark:hover:text-gray-200 cursor-pointer whitespace-nowrap rounded-full px-2.5 py-1.5 font-mono text-xs capitalize
# text-gray-500 max-lg:leading-none lg:py-1 lg:text-sm">RL</a><a href="/blog?tag=ethics" class="from-red-500/30
# to-fuchsia-500/20 hover:bg-linear-to-r hover:text-black dark:hover:text-gray-200 cursor-pointer whitespace-nowrap
# rounded-full px-2.5 py-1.5 font-mono text-xs capitalize text-gray-500 max-lg:leading-none lg:py-1
# lg:text-sm">ethics</a><a href="/blog?tag=diffusion" class="from-cyan-500/30 to-indigo-500/20 hover:bg-linear-to-r
# hover:text-black dark:hover:text-gray-200 cursor-pointer whitespace-nowrap rounded-full px-2.5 py-1.5 font-mono
# text-xs capitalize text-gray-500 max-lg:leading-none lg:py-1 lg:text-sm">Diffusion</a><a href="/blog?tag=game-dev"
# class="from-fuchsia-500/30 to-indigo-500/20 hover:bg-linear-to-r hover:text-black dark:hover:text-gray-200
# cursor-pointer whitespace-nowrap rounded-full px-2.5 py-1.5 font-mono text-xs capitalize text-gray-500
# max-lg:leading-none lg:py-1 lg:text-sm">Game Development</a><a href="/blog?tag=rlhf" class="from-indigo-500/30
# to-orange-500/20 hover:bg-linear-to-r hover:text-black dark:hover:text-gray-200 cursor-pointer whitespace-nowrap
# rounded-full px-2.5 py-1.5 font-mono text-xs capitalize text-gray-500 max-lg:leading-none lg:py-1
# lg:text-sm">RLHF</a><a href="/blog?tag=leaderboard" class="from-pink-500/30 to-teal-500/20 hover:bg-linear-to-r
# hover:text-black dark:hover:text-gray-200 cursor-pointer whitespace-nowrap rounded-full px-2.5 py-1.5 font-mono
# text-xs capitalize text-gray-500 max-lg:leading-none lg:py-1 lg:text-sm">Leaderboard</a><a
# href="/blog?tag=case-studies" class="from-green-500/30 to-purple-500 hover:bg-linear-to-r hover:text-black
# dark:hover:text-gray-200 cursor-pointer whitespace-nowrap rounded-full px-2.5 py-1.5 font-mono text-xs capitalize
# text-gray-500 max-lg:leading-none lg:py-1 lg:text-sm">Case Studies</a></nav>\n\t\t\t\t<div class="SVELTE_HYDRATER
# contents" data-target="ArticlesSearch" data-props="{}">\n\n\n\n\n\n\n\n<button class="hover:shadow-alternate group
# ml-auto mr-6 inline-flex flex-none cursor-pointer rounded-xl border p-2"><svg class="text-gray-500
# group-hover:text-gray-700" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# aria-hidden="true" focusable="false" role="img" width="1em" height="1em" preserveAspectRatio="xMidYMid meet"
# viewBox="0 0 32 32"><path d="M30 28.59L22.45 21A11 11 0 1 0 21 22.45L28.59 30zM5 14a9 9 0 1 1 9 9a9 9 0 0 1-9-9z"
# fill="currentColor"></path></svg></button></div></div>\n\n\t\t\t\n\n\t\t\t\n\t\t\t<div class="pb-6 pt-12"><div
# class="SVELTE_HYDRATER contents" data-target="BlogThumbnail"
# data-props="{&quot;blog&quot;:{&quot;_id&quot;:&quot;67cad6c568a7ec52a996a372&quot;,&quot;authors&quot;:[{&quot;use
# r&quot;:&quot;medmekk&quot;},{&quot;user&quot;:&quot;marcsun13&quot;}],&quot;canonical&quot;:true,&quot;isUpvotedBy
# User&quot;:false,&quot;numCoauthors&quot;:2,&quot;publishedAt&quot;:&quot;2025-03-07T00:00:00.000Z&quot;,&quot;slug
# &quot;:&quot;llm-inference-on-edge&quot;,&quot;title&quot;:&quot;LLM Inference on Edge: A Fun and Easy Guide to run
# LLMs via React Native on your
# Phone!&quot;,&quot;upvotes&quot;:15,&quot;thumbnail&quot;:&quot;/blog/assets/llm_inference_on_edge/thumbnail.png&qu
# ot;,&quot;mainAuthor&quot;:&quot;medmekk&quot;},&quot;blogUrl&quot;:&quot;/blog&quot;,&quot;lang&quot;:&quot;en&quo
# t;,&quot;size&quot;:&quot;lg&quot;}"><a class="flex lg:col-span-2 lg:mb-2 lg:flex-row hover:shadow-alternate
# shadow-xs group relative flex-col overflow-hidden rounded-xl border border-gray-100 transition-shadow "
# href="/blog/llm-inference-on-edge"><div class="aspect-[1.91/1] w-full rounded-r lg:w-4/6 shadow-alternate relative
# flex-none overflow-hidden rounded-lg bg-white"><div class="absolute inset-0 group-hover:opacity-40
# dark:backdrop-brightness-105"></div>\n\n\t\t<img src="/blog/assets/llm_inference_on_edge/thumbnail.png"
# class="h-full w-full object-cover group-hover:brightness-110" alt=""></div>\n\n\t<div class="flex flex-col p-4"><h2
# class="font-serif font-semibold group-hover:underline text-2xl  ">LLM Inference on Edge: A Fun and Easy Guide to
# run LLMs via React Native on your Phone!</h2>\n\n\t\t<p class="mt-3 flex items-center gap-y-1.5 font-mono text-xs
# text-gray-500 flex-wrap">\n\t\t\t\t<span class="inline-flex flex-none items-center">By\xc2\xa0<object
# title="">\n\n<span class="inline-block "><span class="contents"><a href="/medmekk"
# class="hover:underline">medmekk</a></span>\n\t</span></object></span>\n\t\t\t\t<span class="mx-2 h-1 w-1 flex-none
# bg-gray-200"></span>\n\t\t\t<span class="truncate">March 7, 2025</span>\n\t\t\t\n\t\t\t<span class="px-1.5
# text-gray-300">\xe2\x80\xa2</span>\n\n\t\t\t\t<svg class="flex-none w-3 mr-1 text-gray-400"
# xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" role="img"
# width="1em" height="1em" preserveAspectRatio="xMidYMid meet" viewBox="0 0 12 12" fill="transparent"><path
# d="M9.30013 9.29152H9.3H2.7H2.69987C2.62308 9.29154 2.54762 9.27146 2.481 9.23328C2.41437 9.1951 2.3589 9.14015
# 2.32009 9.07389C2.28128 9.00763 2.26048 8.93237 2.25977 8.85558C2.25907 8.7798 2.27796 8.70513 2.31458
# 8.63882L5.62238 2.9426L5.67518 2.85168C5.7059 2.81806 5.74178 2.78928 5.78164 2.76649C5.84813 2.72848 5.9234
# 2.70848 6 2.70848C6.0766 2.70848 6.15187 2.72848 6.21836 2.76649C6.28441 2.80425 6.33953 2.85848 6.37836
# 2.92389L9.68527 8.63855C9.72199 8.70493 9.74093 8.7797 9.74023 8.85558C9.73952 8.93237 9.71872 9.00763 9.67991
# 9.07389C9.6411 9.14015 9.58563 9.1951 9.519 9.23328C9.45238 9.27146 9.37692 9.29154 9.30013 9.29152Z"
# stroke="currentColor"></path></svg>\n\n\t\t\t\t15</p></div></a></div></div>\n\n\t\t\t\n\t\t\t<div class="mb-2 mt-8
# space-y-4 lg:hi
# ..._This content has been truncated to stay below 50000 characters_...
# -1.5 text-gray-300">\xe2\x80\xa2 </span></div>\n\t\t\t\t<div class="truncate"><time datetime="2025-03-05T16:18:47"
# title="Wed, 05 Mar 2025 16:18:47 GMT">5 days ago</time></div>\n\t\t\t\t<span class="px-1.5
# text-gray-300">\xe2\x80\xa2</span>\n\n\t\t\t\t\t<svg class="flex-none w-3 mr-1 text-gray-400"
# xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" role="img"
# width="1em" height="1em" preserveAspectRatio="xMidYMid meet" viewBox="0 0 12 12" fill="transparent"><path
# d="M9.30013 9.29152H9.3H2.7H2.69987C2.62308 9.29154 2.54762 9.27146 2.481 9.23328C2.41437 9.1951 2.3589 9.14015
# 2.32009 9.07389C2.28128 9.00763 2.26048 8.93237 2.25977 8.85558C2.25907 8.7798 2.27796 8.70513 2.31458
# 8.63882L5.62238 2.9426L5.67518 2.85168C5.7059 2.81806 5.74178 2.78928 5.78164 2.76649C5.84813 2.72848 5.9234
# 2.70848 6 2.70848C6.0766 2.70848 6.15187 2.72848 6.21836 2.76649C6.28441 2.80425 6.33953 2.85848 6.37836
# 2.92389L9.68527 8.63855C9.72199 8.70493 9.74093 8.7797 9.74023 8.85558C9.73952 8.93237 9.71872 9.00763 9.67991
# 9.07389C9.6411 9.14015 9.58563 9.1951 9.519 9.23328C9.45238 9.27146 9.37692 9.29154 9.30013 9.29152Z"
# stroke="currentColor"></path></svg>\n\n\t\t\t\t\t6</div></a></article><article class="rounded-xl border
# border-gray-200/70 ring-[2px] ring-gray-400/5 hover:border-gray-200 hover:ring-gray-200/40 dark:border-gray-850
# dark:bg-gray-800/30 dark:ring-transparent dark:hover:border-gray-800 dark:hover:ring-gray-800/30 hover:bg-gray-100
# dark:hover:bg-gray-900 border-0">\n\t\n\t<a href="/blog/prithivMLmods/siglip2-finetune-image-classification"
# tabindex="0" role="link" class="relative block px-3 py-2  cursor-pointer">\n\t\t<h4 class="relative overflow-hidden
# break-words text-smd  ">Fine-Tuning SigLIP 2 for Multi Label Image Classification\n\t\t\t</h4>\n\n\t\t<div
# class="mr-1 flex items-center overflow-hidden whitespace-nowrap text-sm leading-tight text-gray-400"><div
# class="flex shrink-0 items-center">By\n\t\t\t\t\t\t<object title="prithivMLmods"><a href="/prithivMLmods"
# class="flex items-center hover:underline"><img alt="" class="w-3 h-3 rounded-full mx-1.5 flex-none flex-none"
# src="https://cdn-avatars.huggingface.co/v1/production/uploads/65bb837dbfb878f46c77de4c/UVtVbF_3rdt0DC8xTkpL1.jpeg"
# crossorigin="anonymous">\n\t\t\t\t\t\t\t\tprithivMLmods</a></object>\n\t\t\t\t\t\t\n\t\t\t\t\t\t<span class="px-1.5
# text-gray-300">\xe2\x80\xa2 </span></div>\n\t\t\t\t<div class="truncate"><time datetime="2025-03-05T15:50:54"
# title="Wed, 05 Mar 2025 15:50:54 GMT">5 days ago</time></div>\n\t\t\t\t<span class="px-1.5
# text-gray-300">\xe2\x80\xa2</span>\n\n\t\t\t\t\t<svg class="flex-none w-3 mr-1 text-gray-400"
# xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" role="img"
# width="1em" height="1em" preserveAspectRatio="xMidYMid meet" viewBox="0 0 12 12" fill="transparent"><path
# d="M9.30013 9.29152H9.3H2.7H2.69987C2.62308 9.29154 2.54762 9.27146 2.481 9.23328C2.41437 9.1951 2.3589 9.14015
# 2.32009 9.07389C2.28128 9.00763 2.26048 8.93237 2.25977 8.85558C2.25907 8.7798 2.27796 8.70513 2.31458
# 8.63882L5.62238 2.9426L5.67518 2.85168C5.7059 2.81806 5.74178 2.78928 5.78164 2.76649C5.84813 2.72848 5.9234
# 2.70848 6 2.70848C6.0766 2.70848 6.15187 2.72848 6.21836 2.76649C6.28441 2.80425 6.33953 2.85848 6.37836
# 2.92389L9.68527 8.63855C9.72199 8.70493 9.74093 8.7797 9.74023 8.85558C9.73952 8.93237 9.71872 9.00763 9.67991
# 9.07389C9.6411 9.14015 9.58563 9.1951 9.519 9.23328C9.45238 9.27146 9.37692 9.29154 9.30013 9.29152Z"
# stroke="currentColor"></path></svg>\n\n\t\t\t\t\t14</div></a></article><article class="rounded-xl border
# border-gray-200/70 ring-[2px] ring-gray-400/5 hover:border-gray-200 hover:ring-gray-200/40 dark:border-gray-850
# dark:bg-gray-800/30 dark:ring-transparent dark:hover:border-gray-800 dark:hover:ring-gray-800/30 hover:bg-gray-100
# dark:hover:bg-gray-900 border-0">\n\t\n\t<a href="/blog/codyreading/deepseek-checkers" tabindex="0" role="link"
# class="relative block px-3 py-2  cursor-pointer">\n\t\t<h4 class="relative overflow-hidden break-words text-smd
# ">Deepseek R1 Robotic Reasoning with Checkers\n\t\t\t</h4>\n\n\t\t<div class="mr-1 flex items-center
# overflow-hidden whitespace-nowrap text-sm leading-tight text-gray-400"><div class="flex shrink-0
# items-center">By\n\t\t\t\t\t\t<object title="codyreading"><a href="/codyreading" class="flex items-center
# hover:underline"><img alt="" class="w-3 h-3 rounded-full mx-1.5 flex-none flex-none"
# src="/avatars/78d21e0b7732c53672feb17154649dfe.svg"
# crossorigin="anonymous">\n\t\t\t\t\t\t\t\tcodyreading</a></object>\n\t\t\t\t\t\t<span class="pl-1.5">and 4
# others</span>\n\t\t\t\t\t\t<span class="px-1.5 text-gray-300">\xe2\x80\xa2 </span></div>\n\t\t\t\t<div
# class="truncate"><time datetime="2025-03-05T08:27:49" title="Wed, 05 Mar 2025 08:27:49 GMT">5 days
# ago</time></div>\n\t\t\t\t<span class="px-1.5 text-gray-300">\xe2\x80\xa2</span>\n\n\t\t\t\t\t<svg class="flex-none
# w-3 mr-1 text-gray-400" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# aria-hidden="true" role="img" width="1em" height="1em" preserveAspectRatio="xMidYMid meet" viewBox="0 0 12 12"
# fill="transparent"><path d="M9.30013 9.29152H9.3H2.7H2.69987C2.62308 9.29154 2.54762 9.27146 2.481 9.23328C2.41437
# 9.1951 2.3589 9.14015 2.32009 9.07389C2.28128 9.00763 2.26048 8.93237 2.25977 8.85558C2.25907 8.7798 2.27796
# 8.70513 2.31458 8.63882L5.62238 2.9426L5.67518 2.85168C5.7059 2.81806 5.74178 2.78928 5.78164 2.76649C5.84813
# 2.72848 5.9234 2.70848 6 2.70848C6.0766 2.70848 6.15187 2.72848 6.21836 2.76649C6.28441 2.80425 6.33953 2.85848
# 6.37836 2.92389L9.68527 8.63855C9.72199 8.70493 9.74093 8.7797 9.74023 8.85558C9.73952 8.93237 9.71872 9.00763
# 9.67991 9.07389C9.6411 9.14015 9.58563 9.1951 9.519 9.23328C9.45238 9.27146 9.37692 9.29154 9.30013 9.29152Z"
# stroke="currentColor"></path></svg>\n\n\t\t\t\t\t14</div></a></article><article class="rounded-xl border
# border-gray-200/70 ring-[2px] ring-gray-400/5 hover:border-gray-200 hover:ring-gray-200/40 dark:border-gray-850
# dark:bg-gray-800/30 dark:ring-transparent dark:hover:border-gray-800 dark:hover:ring-gray-800/30 hover:bg-gray-100
# dark:hover:bg-gray-900 border-0">\n\t\n\t<a href="/blog/Dzkaka/diffrhythm-open-source-ai-music-generator"
# tabindex="0" role="link" class="relative block px-3 py-2  cursor-pointer">\n\t\t<h4 class="relative overflow-hidden
# break-words text-smd  ">DiffRhythm: Revolutionizing Open Source AI Music Generator \n\t\t\t</h4>\n\n\t\t<div
# class="mr-1 flex items-center overflow-hidden whitespace-nowrap text-sm leading-tight text-gray-400"><div
# class="flex shrink-0 items-center">By\n\t\t\t\t\t\t<object title="Dzkaka"><a href="/Dzkaka" class="flex
# items-center hover:underline"><img alt="" class="w-3 h-3 rounded-full mx-1.5 flex-none flex-none"
# src="https://cdn-avatars.huggingface.co/v1/production/uploads/6448e83a35cc8107ecbc0b36/gUoTpLj9e2zsGRV_5Wgu4.png"
# crossorigin="anonymous">\n\t\t\t\t\t\t\t\tDzkaka</a></object>\n\t\t\t\t\t\t\n\t\t\t\t\t\t<span class="px-1.5
# text-gray-300">\xe2\x80\xa2 </span></div>\n\t\t\t\t<div class="truncate"><time datetime="2025-03-05T03:20:44"
# title="Wed, 05 Mar 2025 03:20:44 GMT">5 days ago</time></div>\n\t\t\t\t<span class="px-1.5
# text-gray-300">\xe2\x80\xa2</span>\n\n\t\t\t\t\t<svg class="flex-none w-3 mr-1 text-gray-400"
# xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" role="img"
# width="1em" height="1em" preserveAspectRatio="xMidYMid meet" viewBox="0 0 12 12" fill="transparent"><path
# d="M9.30013 9.29152H9.3H2.7H2.69987C2.62308 9.29154 2.54762 9.27146 2.481 9.23328C2.41437 9.1951 2.3589 9.14015
# 2.32009 9.07389C2.28128 9.00763 2.26048 8.93237 2.25977 8.85558C2.25907 8.7798 2.27796 8.70513 2.31458
# 8.63882L5.62238 2.9426L5.67518 2.85168C5.7059 2.81806 5.74178 2.78928 5.78164 2.76649C5.84813 2.72848 5.9234
# 2.70848 6 2.70848C6.0766 2.70848 6.15187 2.72848 6.21836 2.76649C6.28441 2.80425 6.33953 2.85848 6.37836
# 2.92389L9.68527 8.63855C9.72199 8.70493 9.74093 8.7797 9.74023 8.85558C9.73952 8.93237 9.71872 9.00763 9.67991
# 9.07389C9.6411 9.14015 9.58563 9.1951 9.519 9.23328C9.45238 9.27146 9.37692 9.29154 9.30013 9.29152Z"
# stroke="currentColor"></path></svg>\n\n\t\t\t\t\t6</div></a></article><article class="rounded-xl border
# border-gray-200/70 ring-[2px] ring-gray-400/5 hover:border-gray-200 hover:ring-gray-200/40 dark:border-gray-850
# dark:bg-gray-800/30 dark:ring-transparent dark:hover:border-gray-800 dark:hover:ring-gray-800/30 hover:bg-gray-100
# dark:hover:bg-gray-900 border-0">\n\t\n\t<a href="/blog/silma-ai/arabic-ai-benchmarks-and-leaderboards"
# tabindex="0" role="link" class="relative block px-3 py-2  cursor-pointer">\n\t\t<h4 class="relative overflow-hidden
# break-words text-smd  ">Arabic AI Benchmarks and Leaderboards\n\t\t\t</h4>\n\n\t\t<div class="mr-1 flex
# items-center overflow-hidden whitespace-nowrap text-sm leading-tight text-gray-400"><div class="flex shrink-0
# items-center">By\n\t\t\t\t\t\t<object title="silma-ai"><a href="/silma-ai" class="flex items-center
# hover:underline"><img alt="" class="w-3 h-3 rounded-xs mx-1.5 flex-none flex-none"
# src="https://cdn-avatars.huggingface.co/v1/production/uploads/63d7acf73130cadcaf827e84/nUnkzwVfdf1MrN5JG_lm5.png"
# crossorigin="anonymous">\n\t\t\t\t\t\t\t\tsilma-ai</a></object>\n\t\t\t\t\t\t\n\t\t\t\t\t\t<span class="px-1.5
# text-gray-300">\xe2\x80\xa2 </span></div>\n\t\t\t\t<div class="truncate"><time datetime="2025-03-04T23:04:11"
# title="Tue, 04 Mar 2025 23:04:11 GMT">5 days ago</time></div>\n\t\t\t\t<span class="px-1.5
# text-gray-300">\xe2\x80\xa2</span>\n\n\t\t\t\t\t<svg class="flex-none w-3 mr-1 text-gray-400"
# xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" role="img"
# width="1em" height="1em" preserveAspectRatio="xMidYMid meet" viewBox="0 0 12 12" fill="transparent"><path
# d="M9.30013 9.29152H9.3H2.7H2.69987C2.62308 9.29154 2.54762 9.27146 2.481 9.23328C2.41437 9.1951 2.3589 9.14015
# 2.32009 9.07389C2.28128 9.00763 2.26048 8.93237 2.25977 8.85558C2.25907 8.7798 2.27796 8.70513 2.31458
# 8.63882L5.62238 2.9426L5.67518 2.85168C5.7059 2.81806 5.74178 2.78928 5.78164 2.76649C5.84813 2.72848 5.9234
# 2.70848 6 2.70848C6.0766 2.70848 6.15187 2.72848 6.21836 2.76649C6.28441 2.80425 6.33953 2.85848 6.37836
# 2.92389L9.68527 8.63855C9.72199 8.70493 9.74093 8.7797 9.74023 8.85558C9.73952 8.93237 9.71872 9.00763 9.67991
# 9.07389C9.6411 9.14015 9.58563 9.1951 9.519 9.23328C9.45238 9.27146 9.37692 9.29154 9.30013 9.29152Z"
# stroke="currentColor"></path></svg>\n\n\t\t\t\t\t9</div></a></article><article class="rounded-xl border
# border-gray-200/70 ring-[2px] ring-gray-400/5 hover:border-gray-200 hover:ring-gray-200/40 dark:border-gray-850
# dark:bg-gray-800/30 dark:ring-transparent dark:hover:border-gray-800 dark:hover:ring-gray-800/30 hover:bg-gray-100
# dark:hover:bg-gray-900 border-0">\n\t\n\t<a href="/blog/silma-ai/arabic-llm-models-list" tabindex="0" role="link"
# class="relative block px-3 py-2  cursor-pointer">\n\t\t<h4 class="relative overflow-hidden break-words text-smd
# ">Arabic LLM Models\n\t\t\t</h4>\n\n\t\t<div class="mr-1 flex items-center overflow-hidden whitespace-nowrap
# text-sm leading-tight text-gray-400"><div class="flex shrink-0 items-center">By\n\t\t\t\t\t\t<object
# title="silma-ai"><a href="/silma-ai" class="flex items-center hover:underline"><img alt="" class="w-3 h-3
# rounded-xs mx-1.5 flex-none flex-none"
# src="https://cdn-avatars.huggingface.co/v1/production/uploads/63d7acf73130cadcaf827e84/nUnkzwVfdf1MrN5JG_lm5.png"
# crossorigin="anonymous">\n\t\t\t\t\t\t\t\tsilma-ai</a></object>\n\t\t\t\t\t\t\n\t\t\t\t\t\t<span class="px-1.5
# text-gray-300">\xe2\x80\xa2 </span></div>\n\t\t\t\t<div class="truncate"><time datetime="2025-03-04T19:30:54"
# title="Tue, 04 Mar 2025 19:30:54 GMT">6 days ago</time></div>\n\t\t\t\t<span class="px-1.5
# text-gray-300">\xe2\x80\xa2</span>\n\n\t\t\t\t\t<svg class="flex-none w-3 mr-1 text-gray-400"
# xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" role="img"
# width="1em" height="1em" preserveAspectRatio="xMidYMid meet" viewBox="0 0 12 12" fill="transparent"><path
# d="M9.30013 9.29152H9.3H2.7H2.69987C2.62308 9.29154 2.54762 9.27146 2.481 9.23328C2.41437 9.1951 2.3589 9.14015
# 2.32009 9.07389C2.28128 9.00763 2.26048 8.93237 2.25977 8.85558C2.25907 8.7798 2.27796 8.70513 2.31458
# 8.63882L5.62238 2.9426L5.67518 2.85168C5.7059 2.81806 5.74178 2.78928 5.78164 2.76649C5.84813 2.72848 5.9234
# 2.70848 6 2.70848C6.0766 2.70848 6.15187 2.72848 6.21836 2.76649C6.28441 2.80425 6.33953 2.85848 6.37836
# 2.92389L9.68527 8.63855C9.72199 8.70493 9.74093 8.7797 9.74023 8.85558C9.73952 8.93237 9.71872 9.00763 9.67991
# 9.07389C9.6411 9.14015 9.58563 9.1951 9.519 9.23328C9.45238 9.27146 9.37692 9.29154 9.30013 9.29152Z"
# stroke="currentColor"></path></svg>\n\n\t\t\t\t\t25</div></a></article></div></div></div></div></main>\n\n\t<footer
# class="b-12 mb-2 flex border-t border-gray-100 md:h-14"><nav class="container relative flex flex-col
# justify-between space-y-2 py-6 text-gray-500 max-md:*:self-start md:flex-row md:items-center md:space-y-0 md:py-0
# md:text-sm"><div class="SVELTE_HYDRATER contents" data-target="ThemeSwitcher"
# data-props="{&quot;theme&quot;:&quot;system&quot;,&quot;isLoggedIn&quot;:false,&quot;menuClassNames&quot;:&quot;md:
# -top-24&quot;,&quot;classNames&quot;:&quot;max-md:mb-5 max-md:*:self-start&quot;}">\n<div class="relative
# inline-block max-md:mb-5 max-md:*:self-start">\n\t<button class="rounded-full border border-gray-100 pl-2 py-1
# pr-2.5  flex items-center text-sm text-gray-500 bg-white hover:bg-purple-50 hover:border-purple-200
# dark:hover:bg-gray-800 dark:hover:border-gray-950 dark:border-gray-800 " type="button">\n\t\t<svg class="mr-1.5
# text-gray-500" xmlns="http://www.w3.org/2000/svg" aria-hidden="true" fill="currentColor" focusable="false"
# role="img" width="1em" height="1em" preserveAspectRatio="xMidYMid meet" viewBox="0 0 32 32"><path d="M29 25H3a1 1 0
# 1 0 0 2h26a1 1 0 1 0 0-2Z" fill="currentColor"></path><path fill-rule="evenodd" clip-rule="evenodd" d="M6 22.5h20a2
# 2 0 0 0 2-2V7a2 2 0 0 0-2-2H6a2 2 0 0 0-2 2v13.5a2 2 0 0 0 2 2ZM7 7a1 1 0 0 0-1 1v11a1 1 0 0 0 1 1h18a1 1 0 0 0
# 1-1V8a1 1 0 0 0-1-1H7Z" fill="currentColor"></path><path d="M6 8a1 1 0 0 1 1-1h18a1 1 0 0 1 1 1v11a1 1 0 0 1-1
# 1H7a1 1 0 0 1-1-1V8Z" fill="currentColor" fill-opacity=".4"></path><path d="M29 25H3a1 1 0 1 0 0 2h26a1 1 0 1 0
# 0-2Z" fill="currentColor"></path></svg>\n\t\t\tSystem theme\n\t\t</button>\n\t\n\t\n\t</div></div>\n\t\t<div
# class="font-semibold text-black md:hidden">Company</div>\n\t\t<a class="hover:underline"
# href="/terms-of-service">TOS</a>\n\t\t<a class="hover:underline" href="/privacy">Privacy</a>\n\t\t<a
# class="hover:underline" href="/huggingface">About</a>\n\t\t<a class="hover:underline"
# href="https://apply.workable.com/huggingface/">Jobs</a>\n\t\t<a href="/" class="max-md:mb-4! max-md:mt-8! group
# flex-none max-md:order-last"><svg class="h-7 w-7 transition-transform group-hover:-translate-y-px" viewBox="0 0 95
# 88" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M47.2119 76.5C66.4037 76.5 81.9619 60.9419 81.9619
# 41.75C81.9619 22.5581 66.4037 7 47.2119 7C28.02 7 12.4619 22.5581 12.4619 41.75C12.4619 60.9419 28.02 76.5 47.2119
# 76.5Z" fill="#FFD21E"></path><path d="M81.9619 41.75C81.9619 22.5581 66.4037 7 47.2119 7C28.02 7 12.4619 22.5581
# 12.4619 41.75C12.4619 60.9419 28.02 76.5 47.2119 76.5C66.4037 76.5 81.9619 60.9419 81.9619 41.75ZM8.46185
# 41.75C8.46185 20.349 25.8108 3 47.2119 3C68.6129 3 85.9619 20.349 85.9619 41.75C85.9619 63.151 68.6129 80.5 47.2119
# 80.5C25.8108 80.5 8.46185 63.151 8.46185 41.75Z" fill="#FF9D0B"></path><path d="M58.5024 32.2915C59.7768 32.7415
# 60.2839 35.3615 61.5713 34.6769C64.0095 33.3805 64.9351 30.353 63.6387 27.9148C62.3423 25.4767 59.3148 24.5511
# 56.8766 25.8475C54.4384 27.1439 53.5128 30.1714 54.8092 32.6096C55.4211 33.7604 57.3632 31.8892 58.5024 32.2915Z"
# fill="#3A3B45"></path><path d="M34.9454 32.2915C33.671 32.7415 33.164 35.3615 31.8766 34.6769C29.4384 33.3805
# 28.5128 30.353 29.8092 27.9148C31.1056 25.4767 34.1331 24.5511 36.5713 25.8475C39.0095 27.1439 39.9351 30.1714
# 38.6387 32.6096C38.0268 33.7604 36.0846 31.8892 34.9454 32.2915Z" fill="#3A3B45"></path><path d="M46.9619
# 56.289C56.7903 56.289 59.9619 47.5261 59.9619 43.0262C59.9619 40.6875 58.3898 41.4236 55.8718 42.6702C53.5449
# 43.8222 50.4102 45.4101 46.9619 45.4101C39.7822 45.4101 33.9619 38.5263 33.9619 43.0262C33.9619 47.5261 37.1334
# 56.289 46.9619 56.289Z" fill="#3A3B45"></path><mask id="mask0" style="mask-type:alpha" maskUnits="userSpaceOnUse"
# x="33" y="41" width="27" height="16"><path d="M46.9619 56.289C56.7903 56.289 59.9619 47.5261 59.9619
# 43.0262C59.9619 40.6875 58.3898 41.4236 55.8718 42.6702C53.5449 43.8222 50.4102 45.4101 46.9619 45.4101C39.7822
# 45.4101 33.9619 38.5263 33.9619 43.0262C33.9619 47.5261 37.1334 56.289 46.9619 56.289Z"
# fill="white"></path></mask><g mask="url(#mask0)"><path d="M47.2119 66.5C52.0018 66.5 55.8848 62.617 55.8848
# 57.8271C55.8848 54.0962 53.5291 50.9156 50.224 49.6915C50.1023 49.6464 49.9794 49.604 49.8553 49.5643C49.0219
# 49.2979 48.1337 52.1623 47.2119 52.1623C46.3506 52.1623 45.5186 49.2797 44.7332 49.5135C41.151 50.5799 38.5389
# 53.8984 38.5389 57.8271C38.5389 62.617 42.4219 66.5 47.2119 66.5Z" fill="#F94040"></path></g><path d="M70.7119
# 37C72.5068 37 73.9619 35.5449 73.9619 33.75C73.9619 31.9551 72.5068 30.5 70.7119 30.5C68.9169 30.5 67.4619 31.9551
# 67.4619 33.75C67.4619 35.5449 68.9169 37 70.7119 37Z" fill="#FF9D0B"></path><path d="M24.2119 37C26.0068 37 27.4619
# 35.5449 27.4619 33.75C27.4619 31.9551 26.0068 30.5 24.2119 30.5C22.4169 30.5 20.9619 31.9551 20.9619 33.75C20.9619
# 35.5449 22.4169 37 24.2119 37Z" fill="#FF9D0B"></path><path class="origin-bottom-right transition-transform
# group-hover:-rotate-6" d="M17.5238 48C15.9048 48 14.4578 48.665 13.4488 49.871C12.8248 50.618 12.1728 51.822
# 12.1198 53.625C11.4408 53.43 10.7878 53.321 10.1778 53.321C8.6278 53.321 7.2278 53.915 6.2378 54.994C4.9658 56.379
# 4.4008 58.081 4.6468 59.784C4.7638 60.595 5.0348 61.322 5.4398 61.995C4.5858 62.686 3.9568 63.648 3.6528
# 64.805C3.4148 65.712 3.1708 67.601 4.4448 69.547C4.3638 69.674 4.2878 69.806 4.2168 69.941C3.4508 71.395 3.4018
# 73.038 4.0778 74.568C5.1028 76.887 7.6498 78.714 12.5958 80.675C15.6728 81.895 18.4878 82.675 18.5128
# 82.682C22.5808 83.737 26.2598 84.273 29.4448 84.273C35.2988 84.273 39.4898 82.48 41.9018 78.944C45.7838 73.25
# 45.2288 68.042 40.2058 63.022C37.4258 60.244 35.5778 56.148 35.1928 55.249C34.4168 52.587 32.3648 49.628 28.9538
# 49.628H28.9528C28.6658 49.628 28.3758 49.651 28.0898 49.696C26.5958 49.931 25.2898 50.791 24.3568 52.085C23.3498
# 50.833 22.3718 49.837 21.4868 49.275C20.1528 48.429 18.8198 48 17.5238 48ZM17.5238 52C18.0338 52 18.6568 52.217
# 19.3438 52.653C21.4768 54.006 25.5928 61.081 27.0998 63.833C27.6048 64.755 28.4678 65.145 29.2448 65.145C30.7868
# 65.145 31.9908 63.612 29.3858 61.664C25.4688 58.733 26.8428 53.942 28.7128 53.647C28.7948 53.634 28.8758 53.628
# 28.9538 53.628C30.6538 53.628 31.4038 56.558 31.4038 56.558C31.4038 56.558 33.6018 62.078 37.3778 65.851C41.1538
# 69.625 41.3488 72.654 38.5968 76.69C36.7198 79.442 33.1268 80.273 29.4448 80.273C25.6258 80.273 21.7108 79.379
# 19.5168 78.81C19.4088 78.782 6.0658 75.013 7.7558 71.805C8.0398 71.266 8.5078 71.05 9.0968 71.05C11.4768 71.05
# 15.8058 74.592 17.6668 74.592C18.0828 74.592 18.3758 74.415 18.4958 73.983C19.2888 71.138 6.4388 69.942 7.5218
# 65.821C7.7128 65.092 8.2308 64.796 8.9588 64.797C12.1038 64.797 19.1598 70.328 20.6388 70.328C20.7518 70.328
# 20.8328 70.295 20.8768 70.225C21.6178 69.029 21.2118 68.194 15.9888 65.033C10.7658 61.871 7.0998 59.969 9.1848
# 57.699C9.4248 57.437 9.7648 57.321 10.1778 57.321C13.3488 57.322 20.8408 64.14 20.8408 64.14C20.8408 64.14 22.8628
# 66.243 24.0858 66.243C24.3668 66.243 24.6058 66.132 24.7678 65.858C25.6348 64.396 16.7148 57.636 16.2118
# 54.847C15.8708 52.957 16.4508 52 17.5238 52Z" fill="#FF9D0B"></path><path class="origin-bottom-right
# transition-transform group-hover:-rotate-6" d="M38.5967 76.6898C41.3487 72.6538 41.1537 69.6248 37.3777
# 65.8508C33.6017 62.0778 31.4037 56.5578 31.4037 56.5578C31.4037 56.5578 30.5827 53.3518 28.7127 53.6468C26.8427
# 53.9418 25.4697 58.7328 29.3867 61.6638C33.3037 64.5938 28.6067 66.5848 27.0997 63.8328C25.5927 61.0808 21.4777
# 54.0058 19.3437 52.6528C17.2107 51.2998 15.7087 52.0578 16.2117 54.8468C16.7147 57.6358 25.6357 64.3958 24.7677
# 65.8588C23.8997 67.3208 20.8407 64.1398 20.8407 64.1398C20.8407 64.1398 11.2687 55.4288 9.18465 57.6988C7.10065
# 59.9688 10.7657 61.8708 15.9887 65.0328C21.2127 68.1938 21.6177 69.0288 20.8767 70.2248C20.1347 71.4208 8.60465
# 61.6998 7.52165 65.8208C6.43965 69.9418 19.2887 71.1378 18.4957 73.9828C17.7027 76.8288 9.44465 68.5978 7.75565
# 71.8048C6.06565 75.0128 19.4087 78.7818 19.5167 78.8098C23.8267 79.9278 34.7727 82.2968 38.5967 76.6898Z"
# fill="#FFD21E"></path><path class="origin-bottom-left transition-transform group-hover:rotate-6" d="M77.3999
# 48C79.0189 48 80.4659 48.665 81.4749 49.871C82.0989 50.618 82.7509 51.822 82.8039 53.625C83.4829 53.43 84.1359
# 53.321 84.7459 53.321C86.2959 53.321 87.6959 53.915 88.6859 54.994C89.9579 56.379 90.5229 58.081 90.2769
# 59.784C90.1599 60.595 89.8889 61.322 89.4839 61.995C90.3379 62.686 90.9669 63.648 91.2709 64.805C91.5089 65.712
# 91.7529 67.601 90.4789 69.547C90.5599 69.674 90.6359 69.806 90.7069 69.941C91.4729 71.395 91.5219 73.038 90.8459
# 74.568C89.8209 76.887 87.2739 78.714 82.3279 80.675C79.2509 81.895 76.4359 82.675 76.4109 82.682C72.3429 83.737
# 68.6639 84.273 65.4789 84.273C59.6249 84.273 55.4339 82.48 53.0219 78.944C49.1399 73.25 49.6949 68.042 54.7179
# 63.022C57.4979 60.244 59.3459 56.148 59.7309 55.249C60.5069 52.587 62.5589 49.628 65.9699 49.628H65.9709C66.2579
# 49.628 66.5479 49.651 66.8339 49.696C68.3279 49.931 69.6339 50.791 70.5669 52.085C71.5739 50.833 72.5519 49.837
# 73.4369 49.275C74.7709 48.429 76.1039 48 77.3999 48ZM77.3999 52C76.8899 52 76.2669 52.217 75.5799 52.653C73.4469
# 54.006 69.3309 61.081 67.8239 63.833C67.3189 64.755 66.4559 65.145 65.6789 65.145C64.1369 65.145 62.9329 63.612
# 65.5379 61.664C69.4549 58.733 68.0809 53.942 66.2109 53.647C66.1289 53.634 66.0479 53.628 65.9699 53.628C64.2699
# 53.628 63.5199 56.558 63.5199 56.558C63.5199 56.558 61.3219 62.078 57.5459 65.851C53.7699 69.625 53.5749 72.654
# 56.3269 76.69C58.2039 79.442 61.7969 80.273 65.4789 80.273C69.2979 80.273 73.2129 79.379 75.4069 78.81C75.5149
# 78.782 88.8579 75.013 87.1679 71.805C86.8839 71.266 86.4159 71.05 85.8269 71.05C83.4469 71.05 79.1179 74.592
# 77.2569 74.592C76.8409 74.592 76.5479 74.415 76.4279 73.983C75.6349 71.138 88.4849 69.942 87.4019 65.821C87.2109
# 65.092 86.6929 64.796 85.9649 64.797C82.8199 64.797 75.7639 70.328 74.2849 70.328C74.1719 70.328 74.0909 70.295
# 74.0469 70.225C73.3059 69.029 73.7119 68.194 78.9349 65.033C84.1579 61.871 87.8239 59.969 85.7389 57.699C85.4989
# 57.437 85.1589 57.321 84.7459 57.321C81.5749 57.322 74.0829 64.14 74.0829 64.14C74.0829 64.14 72.0609 66.243
# 70.8379 66.243C70.5569 66.243 70.3179 66.132 70.1559 65.858C69.2889 64.396 78.2089 57.636 78.7119 54.847C79.0529
# 52.957 78.4729 52 77.3999 52Z" fill="#FF9D0B"></path><path class="origin-bottom-left transition-transform
# group-hover:rotate-6" d="M56.3271 76.6898C53.5751 72.6538 53.7701 69.6248 57.5461 65.8508C61.3221 62.0778 63.5201
# 56.5578 63.5201 56.5578C63.5201 56.5578 64.3411 53.3518 66.2111 53.6468C68.0811 53.9418 69.4541 58.7328 65.5371
# 61.6638C61.6201 64.5938 66.3171 66.5848 67.8241 63.8328C69.3311 61.0808 73.4461 54.0058 75.5801 52.6528C77.7131
# 51.2998 79.2151 52.0578 78.7121 54.8468C78.2091 57.6358 69.2881 64.3958 70.1561 65.8588C71.0241 67.3208 74.0831
# 64.1398 74.0831 64.1398C74.0831 64.1398 83.6551 55.4288 85.7391 57.6988C87.8231 59.9688 84.1581 61.8708 78.9351
# 65.0328C73.7111 68.1938 73.3061 69.0288 74.0471 70.2248C74.7891 71.4208 86.3191 61.6998 87.4021 65.8208C88.4841
# 69.9418 75.6351 71.1378 76.4281 73.9828C77.2211 76.8288 85.4791 68.5978 87.1681 71.8048C88.8581 75.0128 75.5151
# 78.7818 75.4071 78.8098C71.0971 79.9278 60.1511 82.2968 56.3271 76.6898Z"
# fill="#FFD21E"></path></svg></a>\n\t\t<div class="max-md:mt-8! font-semibold text-black
# md:hidden">Website</div>\n\n\t\t<a class="hover:underline" href="/models">Models</a>\n\t\t<a
# class="hover:underline" href="/datasets">Datasets</a>\n\t\t<a class="hover:underline"
# href="/spaces">Spaces</a>\n\t\t<a class="hover:underline" href="/pricing">Pricing</a>\n\t\t<a
# class="hover:underline"
# href="/docs">Docs</a></nav></footer></div>\n\n\t\t<script>\n\t\t\timport("\\/front\\/build\\/kube-6eb1cac\\/index.j
# s");\n\t\t\twindow.moonSha = "kube-6eb1cac\\/";\n\t\t\twindow.__hf_deferred = {};\n\t\t</script>\n\n\t\t<!-- Stripe
# -->\n\t\t<script>\n\t\t\tif (["hf.co", "huggingface.co"].includes(window.location.hostname)) {\n\t\t\t\tconst
# script = document.createElement("script");\n\t\t\t\tscript.src = "https://js.stripe.com/v3/";\n\t\t\t\tscript.async
# = true;\n\t\t\t\tdocument.head.appendChild(script);\n\t\t\t}\n\t\t</script>\n\t</body>\n</html>\n'
#
# Out: None
# [Step 1: Duration 3.52 seconds| Input tokens: 1,977 | Output tokens: 88]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   soup = BeautifulSoup(response.content, 'html.parser')
#   title = soup.find('title').get_text()
#   final_answer(title)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: Hugging Face – Blog
# [Step 2: Duration 1.94 seconds| Input tokens: 26,061 | Output tokens: 150]
# 'Hugging Face – Blog'

# %%
web_agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model,
    name="web_search2",
    description="Runs web searches for you. Give it your query as an argument."
)

manager_agent = CodeAgent(
    tools=[], model=model, managed_agents=[web_agent]
)

manager_agent.run("Who is the CEO of Hugging Face?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Who is the CEO of Hugging Face?                                                                                 │
# │                                                                                                                 │
# ╰─ AzureOpenAIServerModel - gpt-4o-glob-2024-05-13 ───────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Let's perform a web search to find the current CEO of Hugging Face
#   result = web_search2(task="current CEO of Hugging Face")
#   print(result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ╭───────────────────────────────────────────── New run - web_search2 ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │ You're a helpful agent named 'web_search2'.                                                                     │
# │ You have been submitted this task by your manager.                                                              │
# │ ---                                                                                                             │
# │ Task:                                                                                                           │
# │ current CEO of Hugging Face                                                                                     │
# │ ---                                                                                                             │
# │ You're helping your manager solve a wider task: so make sure to not provide a one-line answer, but give as much │
# │ information as possible to give them a clear understanding of the answer.                                       │
# │                                                                                                                 │
# │ Your final_answer WILL HAVE to contain these parts:                                                             │
# │ ### 1. Task outcome (short version):                                                                            │
# │ ### 2. Task outcome (extremely detailed version):                                                               │
# │ ### 3. Additional context (if relevant):                                                                        │
# │                                                                                                                 │
# │ Put all these in your final_answer tool, everything that you do not pass as an argument to final_answer will be │
# │ lost.                                                                                                           │
# │ And even if your task resolution is not successful, please return as much context as possible, so that your     │
# │ manager can act upon this feedback.                                                                             │
# │                                                                                                                 │
# ╰─ AzureOpenAIServerModel - gpt-4o-glob-2024-05-13 ───────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_result = web_search(query="current CEO of Hugging Face")
#   print(search_result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [List of Hugging Face Executives & Org Chart | Clay](https://www.clay.com/dossier/hugging-face-executives)
# At the top of Hugging Face's organizational chart is Clement Delangue, the Co-Founder and CEO, who oversees the
# company's overall vision and strategic direction. Directly reporting to him are Julien Chaumond, the Co-Founder and
# CTO, and Thomas Wolf, the Co-Founder and Chief Science Officer, both of whom play crucial roles in driving ...
#
# [Who is the CEO of Hugging Face? Clem Delangue 's Bio - Clay](https://www.clay.com/dossier/hugging-face-ceo)
# Clément Delangue is the CEO and co-founder of Hugging Face, an open and collaborative platform for AI builders.
# With a background in entrepreneurship and education from Stanford University, Delangue has played a pivotal role in
# growing Hugging Face into a leading AI platform valued at $4.5 billion, hosting over a million open-source
# repositories and serving more than 15,000 companies ...
#
# [Clément Delangue, CEO of Hugging Face, built the GitHub of
# AI](https://www.fastcompany.com/90909717/clement-delangue-ceo-hugging-face-most-creative-people-2023)
# How Clément Delangue, CEO of Hugging Face, built the GitHub of AI. Users have shared more than 250,000 models and
# 50,000 data sets, helping propel the company to a $2 billion valuation. LOGIN
#
# [Clem Delangue - Hugging Face - LinkedIn](https://www.linkedin.com/in/clementdelangue)
# My first startup experience was with Moodstocks - building machine learning for computer vision. The company went
# on to get acquired by Google. I never lost my passion for building AI products ...
#
# [Clément Delangue: The 100 Most Influential People in AI 2023 -
# TIME](https://time.com/collection/time100-ai/6308994/clement-delangue/)
# C lément Delangue is the CEO of Hugging Face, an open-source, for-profit machine-learning platform where
# researchers from around the world convene to share their AI models, datasets, and best ...
#
# [Meet Hugging Face CEO Clement Delangue |
# ICT-Mirror](https://ictmirror.com/entertainment/hugging-face-ceo-clement-delangue/)
# Entrepreneurial Journey Of The Hugging Face CEO Clement Delangue. Clement Delangue is the CEO and co-founder of
# Hugging Face. He is a native of quaint town of La Bassee in northern France.. Growing up in an ordinary household,
# Clem's interest in technology was piqued when he got his first computer at the age of 12.
#
# [How Hugging Face Grew to a $4.5B Valuation in Seven Years](https://www.starterstory.com/hugging-face-breakdown)
# Clement Delangue is the co-founder and CEO of Hugging Face, a company revolutionizing the AI and natural language
# processing space. Born in La Bassée, France, Delangue began his career in the product team of Moodstocks, a machine
# learning startup later acquired by Google. He holds a degree from ESCP Business School and has taken computer ...
#
# [Hugging Face CEO and Key Executive Team | Craft.co](https://craft.co/hugging-face/executives)
# Hugging Face's Co-Founder, CEO is Clement Delangue. Other executives include Julien Chaumond, Co-Founder, CTO;
# Thomas Wolf, Co-Founder - CSO and 1 others. See the full leadership team at Craft.
#
# [Hugging Face CEO, Founder, Key Executive Team, Board of Directors
# ...](https://www.cbinsights.com/company/hugging-face/people)
# Explore {Hugging Face's key management people. Discover current leadership team members including founders, CEO,
# other executives and board directors. ... Hugging Face's current Founder, Chief Executive Officer is Clément
# Delangue. Name. Work History. Title. Status. Clément Delangue. Mention Solutions, Moodstocks, VideoNotes, and eBay.
#
# [Clément Delangue - CEO & Co-Founder @ Hugging Face -
# Crunchbase](https://www.crunchbase.com/person/clement-delangue)
# Clément Delangue has 2 current jobs as CEO & Co-Founder at Hugging Face and Evangelist at Milaap. Additionally,
# Clément Delangue has had 4 past jobs including Co-Founder & CEO at VideoNot.es. Hugging Face CEO & Co-Founder Jul
# 2016. Milaap Evangelist Dec 1, 2010. Organization Name . Title At Company . Start Date . End Date . VideoNot.es .
#
# Out: None
# [Step 1: Duration 2.17 seconds| Input tokens: 2,174 | Output tokens: 67]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Preparing the detailed final answer
#   task_outcome_short = "The current CEO of Hugging Face is Clément Delangue."
#   task_outcome_detailed = """
#   Clément Delangue is the co-founder and CEO of Hugging Face, a renowned AI company. He holds a degree from ESCP
#   Business School and has experience in entrepreneurship and education from Stanford University.
#   Delangue has played a pivotal role in growing Hugging Face into a leading AI platform valued at $4.5 billion,
#   hosting over a million open-source repositories, serving more than 15,000 companies, and is known for
#   establishing the "GitHub of AI".
#   His entrepreneurial journey began with Moodstocks, a machine learning startup that was later acquired by
#   Google. He continues to be a prominent figure in AI, being recognized in TIME's 100 Most Influential People in
#   AI for 2023. Hugging Face's growth under his leadership includes the sharing of more than 250,000 AI models and
#   50,000 datasets, revolutionizing the AI and NLP landscape.
#   """
#   additional_context = """
#   Clement Delangue is originally from La Bassée, France, and his interest in technology was piqued when he
#   received his first computer at the age of 12. Besides his current role, he has had multiple notable positions
#   including Evangelist at Milaap and Co-Founder & CEO at VideoNot.es. He has a strong background in building
#   machine learning for computer vision.
#   """
#
#   final_answer_content = f"""
#   ### 1. Task outcome (short version):
#   {task_outcome_short}
#   ### 2. Task outcome (extremely detailed version):
#   {task_outcome_detailed}
#   ### 3. Additional context (if relevant):
#   {additional_context}
#   """
#
#   final_answer(final_answer_content)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer:
# ### 1. Task outcome (short version):
# The current CEO of Hugging Face is Clément Delangue.
# ### 2. Task outcome (extremely detailed version):
#
# Clément Delangue is the co-founder and CEO of Hugging Face, a renowned AI company. He holds a degree from ESCP
# Business School and has experience in entrepreneurship and education from Stanford University.
# Delangue has played a pivotal role in growing Hugging Face into a leading AI platform valued at $4.5 billion,
# hosting over a million open-source repositories, serving more than 15,000 companies, and is known for establishing
# the "GitHub of AI".
# His entrepreneurial journey began with Moodstocks, a machine learning startup that was later acquired by Google. He
# continues to be a prominent figure in AI, being recognized in TIME's 100 Most Influential People in AI for 2023.
# Hugging Face's growth under his leadership includes the sharing of more than 250,000 AI models and 50,000 datasets,
# revolutionizing the AI and NLP landscape.
#
# ### 3. Additional context (if relevant):
#
# Clement Delangue is originally from La Bassée, France, and his interest in technology was piqued when he received
# his first computer at the age of 12. Besides his current role, he has had multiple notable positions including
# Evangelist at Milaap and Co-Founder & CEO at VideoNot.es. He has a strong background in building machine learning
# for computer vision.
# [Step 2: Duration 3.46 seconds| Input tokens: 5,480 | Output tokens: 478]
# Execution logs:
# Here is the final answer from your managed agent 'web_search2':
#
# ### 1. Task outcome (short version):
# The current CEO of Hugging Face is Clément Delangue.
# ### 2. Task outcome (extremely detailed version):
#
# Clément Delangue is the co-founder and CEO of Hugging Face, a renowned AI company. He holds a degree from ESCP
# Business School and has experience in entrepreneurship and education from Stanford University.
# Delangue has played a pivotal role in growing Hugging Face into a leading AI platform valued at $4.5 billion,
# hosting over a million open-source repositories, serving more than 15,000 companies, and is known for establishing
# the "GitHub of AI".
# His entrepreneurial journey began with Moodstocks, a machine learning startup that was later acquired by Google. He
# continues to be a prominent figure in AI, being recognized in TIME's 100 Most Influential People in AI for 2023.
# Hugging Face's growth under his leadership includes the sharing of more than 250,000 AI models and 50,000 datasets,
# revolutionizing the AI and NLP landscape.
#
# ### 3. Additional context (if relevant):
#
# Clement Delangue is originally from La Bassée, France, and his interest in technology was piqued when he received
# his first computer at the age of 12. Besides his current role, he has had multiple notable positions including
# Evangelist at Milaap and Co-Founder & CEO at VideoNot.es. He has a strong background in building machine learning
# for computer vision.
#
#
#
# Out: None
# [Step 1: Duration 6.76 seconds| Input tokens: 3,306 | Output tokens: 411]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Based on the web-search result, the current CEO of Hugging Face is Clément Delangue.
#   final_answer("Clément Delangue")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: Clément Delangue
# [Step 2: Duration 0.75 seconds| Input tokens: 5,833 | Output tokens: 448]
# 'Clément Delangue'

# %% [markdown]
# https://vladiliescu.net/smolagents-with-azure-openai/

# %%
agent = CodeAgent(tools=[DuckDuckGoSearchTool(), VisitWebpageTool()], model=model)
agent.run("How many eggs can you fit in a bus?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ How many eggs can you fit in a bus?                                                                             │
# │                                                                                                                 │
# ╰─ AzureOpenAIServerModel - gpt-4o-glob-2024-05-13 ───────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   web_search(query="average volume of a bus in cubic meters")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out: ## Search Results
#
# [Convert Double-decker Buses to Cubic Meters -
# Sixus](https://sixus-converter.com/double-decker-buses/cubic-meters/1)
# The resulting volume is rounded to 75 cubic meters. Value. One double-decker bus is 75 cubic meters. Other Real
# World Volumes. shoebox: shbx: 11 liters: double-decker bus: ddb: 75 cubic meters: Olympic swimming pool: osp: 3 750
# cubic meters: Great Pyramid of Giza-2.5 million cubic meters: Grand Canyon: gc: 4.17 trillion cubic meters:
#
# [How many cubic meters is a double decker bus? -
# AnswersAll](https://answer-all.com/science/how-many-cubic-meters-is-a-double-decker-bus/)
# The average double deck bus is 1,144 cubic metres - that could hold 200,612 pints of milk. ... Standard City Bus
# The approximate average city bus length is 14 meters, or between 35 and 45 feet. Bus width is typically between 95
# and 105 inches, or 8 to 9 feet. ... total volume equals 112.5 cubic metres. A little division sum 400 000 (the ...
#
# [How to Visualize Cubic Feet (and Meters) - Illuminating
# Facts](https://illuminatingfacts.com/how-to-visualize-cubic-feet-and-meters/)
# Volume of the school bus in cubic meters: 27.18 cubic meters: Volume of a golf ball: 2.5 cubic inches: Volume of
# the school bus in cubic inches: ... Therefore, assembling seven of it can give you the 40 cubic feet size. 20 Car
# Fuel Tanks: On average, one car fuel tank is around 2.13 cubic feet. Smaller ones can hold around 12 gallons while
# ...
#
# [Volume Calculator](https://www.omnicalculator.com/math/volume)
# The volume of the Earth is approximately equal to 1.08321×10 12 km³ (1.08 trillion cubic kilometers), or 2.59876×10
# 11 cu mi (259 billion cubic miles). You can get this result using the sphere volume formula (4/3) × π × radius³ and
# assuming that the Earth's average radius is 6,371 kilometers (3,958.76 mi).
#
# [Buses Dimensions & Drawings | Dimensions.com](https://www.dimensions.com/collection/buses)
# Buses are large road vehicles designed to carry numerous passengers at once. They come in various sizes and
# configurations, from small minibuses to full-sized single-deck and double-deck vehicles. Buses typically have
# multiple rows of seats and dedicated standing areas.
#
# [[Request] How many watermelons could actually fit in a school
# bus?](https://www.reddit.com/r/theydidthemath/comments/izm0fy/request_how_many_watermelons_could_actually_fit/)
# With these figures then, a typical bus cabin has a volume of 10×2.5×2=50 cubic meters. This might not sound like a
# lot, but keep in mind that a cubic meter is quite big - a cubic meter of water weighs 1000kg. So how big is an
# average watermelon? This is... difficult, because watermelons aren't spherical. They're actually approximate
# ellipsoids.
#
# [Double Decker Buses and Swimming Pools -
# Blogger](https://busdriving.blogspot.com/2006/08/double-decker-buses-and-swimming-pools.html)
# I had a look at the size of the double Decker buses that I drive and they are 10.504 m long, 4,2 m high and 2.55 m
# wide; total volume equals 112.5 cubic metres. A little division sum 400 000 (the volume of all those swimming pools
# full of nice safe nuclear waste)/112.5 (the volume of my bus) = 3555 buses.
#
# [School Bus Dimensions and Guidelines - MeasuringKnowHow](https://www.measuringknowhow.com/school-bus-dimensions/)
# The Type C school bus, the most popular bus type, which seats between 54 and 78 students, is between 20.9 and 38.9
# feet (6.37 to 11.86 meters) long, 9.9 to 10.4 feet (3.02 to 3.17 meters) tall, and 7.75 to 8 feet (2.36 to 2.44
# meters) wide.
#
# [PDF](https://amritsarcorp.com/Vol_II+A+-+Bus+Specs.pdf)
# Bus Specifications (Indicative) 1. Low Floor AC buses (400 MM Platform) : Tata Motors Ltd. - Model No. LPO 1624 RE
# LE AC bus (30 Buses) Sr No Parameters Details 1 Doors Minimum Width of Service Doors 1. 1300mm door aperture. 1100
# at handhold level after fitment of doors. 2. Doors mandatory 3. Type of Door opening : Preferably in swinging
#
# [What metric unit would you use to measure a
# bus?](https://teacherscollegesj.org/what-metric-unit-would-you-use-to-measure-a-bus/)
# How long is a school bus in meters? On average the school bus length is around 10,65 meters. ... unit of volume in
# the metric system, equal to one cubic decimetre (0.001 cubic metre). ... From 1901 to 1964 the litre was defined as
# the volume of one kilogram of pure water at 4 °C (39.2 °F) and standard atmospheric pressure; in 1964 the ...
# [Step 1: Duration 2.25 seconds| Input tokens: 2,083 | Output tokens: 73]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   web_search(query="average volume of an egg in cubic centimeters")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out: ## Search Results
#
# [Is 1 cubic centimeters as big as an Egg? | The Measure of
# Things](https://www.themeasureofthings.com/singleresult.php?comp=volume&unit=cc&amt=01&i=420)
# A typical egg — of large size as defined by the United State Department of Agriculture — has a volume of 68 cubic
# centimeters.Each year, American farms produce 69,000,000,000 eggs.
#
# [Egg Surface Area and Volume Calculator | Good
# Calculators](https://goodcalculators.com/egg-surface-area-and-volume-calculator/)
# The Surface Area of an Egg. To calculate the surface area of an egg, you will need to use cos-1, which is the
# inverse trigonometric function arccos.You can calculate the surface area of an egg using the arccos button on a
# scientific calculator; however, make sure that the mode is on radians as opposed to degrees.The formula used to
# compute the surface area of an egg is as follows:
#
# [What is the Volume of an Egg? - Produce Converter: How Much Is
# In](https://www.howmuchisin.com/produce_converters/volume-of-an-egg)
# How much egg white is in an average egg. And what is the total volume of an egg. It may "crack you up" to realize
# that 1 egg yolk measures 1 to 1.25 tablespoon and the white is 2 tablespoons. This makes the whole shelled egg
# measure about 3 tablespoons. Using these same eggs, the yolk weighed .6 ounce (18 grams) and egg white was 1.05
# ounces ...
#
# [[FREE] The eggs of birds and other animals come in many different ...](https://brainly.com/question/12544902)
# The average diameter of the egg is 4.1 centimeters, so the radius r is half of that: r = 2 4.1 = 2.05 cm. Now we
# can plug the radius into the volume formula: V = 3 4 π (2.05) 3. Calculating this: V = 3 4 π (8.615125) ≈ 3 4 ×
# 27.086391 ≈ 36.1151 cm 3. Rounding to the nearest tenth, the volume of one turtle egg is approximately 36.1 cubic
# ...
#
# [Average size of chicken eggs | World Food and
# Wine](https://www.worldfoodwine.com/table-talk/average-size-of-chicken-eggs)
# 1 medium (M) egg - with a weight greater than 1.75 oz (50g) will yield 4 Tbs (about 43 ml) Other possibilities:
# Approximate the volume of a chicken egg considering the egg a sphere. If you have the average density of an egg -
# the yolk and the white have different densities - you can apply the formula Volume = mass x density
#
# [Egg Volume - Two Measurements - Centimetres](https://www.spikevm.com/calculators/tanks/egg-cm.php)
# the volume in cubic feet; the capacity of the tank in centilitres; the capacity in litres; the capacity in US
# gallons ... ²H where V is the volume 흅 = 3.14159265 D the diameter of the egg tank on its widest point H the
# height of the egg Conversions one cubic centimetre (cm³) = 0.1 centilitres (cl) one cubic centimetre (cm³) = 0.001
# litres ...
#
# [How do you calculate the volume of an egg? -
# WisdomAnswer](https://wisdomanswer.com/how-do-you-calculate-the-volume-of-an-egg/)
# An egg with a width of two inches (W = one inch) and lengths one inch and 1.5 inches therefore has a volume of
# 5.233 cubic inches. What is the mass and volume of an egg? When I took the egg out of the water, there were about
# 190 mL of water left, so the egg's volume was about 60 mL, and its mass was 56 grams [gm].
#
# [How big is 1 cubic centimeters? | The Measure of
# Things](https://www.themeasureofthings.com/results.php?comp=volume&unit=cc&amt=1)
# A typical egg — of large size as defined by the United State Department of Agriculture — has a volume of 68 cubic
# centimeters. Each year, American farms produce 69,000,000,000 eggs. Each year, American farms produce
# 69,000,000,000 eggs.
#
# [Volume of an Egg - Liters per Size - Rechneronline](https://rechneronline.de/litre/egg.php)
# Theoretically, the height and width should be measured on the inside. A hen's egg has a shell thickness of about
# 0.3 to 0.5 millimeters, twice the thickness must be subtracted from the height and width on the outside. Example:
# an egg with a height of 5 cm and a width of 4.4 cm, with a shell thickness of 0.4 mm, has a volume of 4.8
# centiliters.
#
# [Pigeon Egg Dimensions: Size, Volume, Weight, Surface Area, And Aspect
# Ratio](https://sciencegate.blog/pigeon-egg-dimensions/)
# On average, they measure around 1.5 inches in length and 1.1 inches in width, with a circumference of approximately
# 4.5 inches. The egg's volume is about 6 cubic centimeters, and it weighs around 15 grams. The egg's surface area is
# approximately 10 square centimeters, and its aspect ratio (height-to-width ratio) is around 1.3.
# [Step 2: Duration 3.11 seconds| Input tokens: 5,491 | Output tokens: 154]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   bus_volume = 112.5  # in cubic meters
#   egg_volume = 0.068 / 1000  # converting cubic centimeters to cubic meters, resulting in 0.000068 cubic meters
#
#   number_of_eggs = bus_volume / egg_volume
#   final_number_of_eggs = int(number_of_eggs)
#   print(final_number_of_eggs)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# 1654411
#
# Out: None
# [Step 3: Duration 2.71 seconds| Input tokens: 10,231 | Output tokens: 335]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer(1654411)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: 1654411
# [Step 4: Duration 1.05 seconds| Input tokens: 15,298 | Output tokens: 376]
# 1654411
